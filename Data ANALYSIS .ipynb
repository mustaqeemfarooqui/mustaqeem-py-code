# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("P1-SuperStoreUS-2015 - Orders.csv")

# %%
data.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0   Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
#
#   Region State or Province         City  Postal Code Order Date  Ship Date  \
# 0   West        Washington    Anacortes        98221   1/7/2015   1/8/2015
# 1   West        California  San Gabriel        91776  6/13/2015  6/15/2015
#
#       Profit Quantity ordered new    Sales Order ID
# 0     4.5600                    4    13.01    88522
# 1  4390.3665                   12  6362.85    90193
#
# [2 rows x 25 columns]

# %% [markdown]
# # missing value find code

# %%
# missing value find code 
data.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# # missing value fill code

# %%
# missing value fill code 
data["Product Base Margin"].fillna(data["Product Base Margin"].mean(),inplace=True)

# %%
# data check code
data.shape
# Out:
# (1952, 25)

# %% [markdown]
# # Order Priority

# %%
data["Order Priority"].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         391
# Medium           376
# Name: count, dtype: int64

# %%
# colum check code 
data["Order Priority"].unique()
# Out:
# array(['High', 'Not Specified', 'Critical', 'Medium', 'Low', 'Critical '],
#       dtype=object)

# %%
# replace colum code 
data ["Order Priority"] = data ['Order Priority'].replace("Critical ","Critical")

# %%
# garaf size low code 
plt.figure(figsize=(5,4))
# garaf tittle code 
plt.title("count of Order Priority")
# garaf banaye k code 
sns.countplot(x="Order Priority", data=data)
# garaf save code
plt.savefig("count of Order Priority.jpg")
plt.show()

# %% [markdown]
# # Ship Mode

# %%
data["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       1437
# Delivery Truck     275
# Express Air        240
# Name: count, dtype: int64

# %% [markdown]
# # x y value check code
# # x value name hai
# # y value persanttage

# %%
# x y value check code 
# x value name hai
# y value persanttage
x = data["Ship Mode"].value_counts().index
y = data["Ship Mode"].value_counts().values

# %% [markdown]
# # gool garaf code

# %%
# gool garaf code
plt.figure(figsize=(5,4))
plt.pie(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # garaf name show code
# # garaf rotate angle code
# # persanttage show code

# %%
# garaf name show code
#plt.pie(y,labels=x)
# garaf rotate angle code
#plt.pie(y,labels=x,startangle=60)
# persanttage show code
plt.pie(y,labels=x,startangle=60, autopct="%0.2f%%")
plt.legend(loc=3) # garaf legend code
plt.title("Ship Mode")
#plt.savefig("Ship Mode.jpg")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Product Category and Shipping Mode check code

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode", data=data, hue="Product Category")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Customer Segment check code

# %%
data["Customer Segment"].unique()
# Out:
# array(['Corporate', 'Home Office', 'Small Business', 'Consumer'],
#       dtype=object)

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="Customer Segment", data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Product Category	sale check code

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Product Sub-Category check code

# %%
data["Product Sub-Category"].unique()
# Out:
# array(['Pens & Art Supplies', 'Chairs & Chairmats', 'Office Furnishings',
#        'Rubber Bands', 'Envelopes', 'Telephones and Communication',
#        'Office Machines', 'Paper', 'Binders and Binder Accessories',
#        'Labels', 'Storage & Organization', 'Tables',
#        'Scissors, Rulers and Trimmers', 'Computer Peripherals',
#        'Bookcases', 'Appliances', 'Copiers and Fax'], dtype=object)

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=data, hue="Product Sub-Category")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  # alag alag geraf code

# %% [markdown]
# # Office Supplies geraf

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=data[data ["Product Category"]=="Office Supplies"], hue="Product Sub-Category")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Furniture geraf

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=data[data ["Product Category"]=="Furniture"], hue="Product Sub-Category")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Technology geraf

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=data[data ["Product Category"]=="Technology"], hue="Product Sub-Category")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Order Date check code

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])

# Now you can extract the year component
data["Order Year"] = data["Order Date"].dt.year

# %%
 data["Order Year"].value_counts()
# Out:
# Order Year
# 2015    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Year", data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Product Category Profit check code

# %%
plt.figure(figsize=(5, 4))  # Set the figure size
sns.barplot(x="Product Category", y="Profit", data=data, estimator='sum')
plt.show()

# %% [markdown]
# # State or Province sale check code

# %%
data["State or Province"].value_counts()
# Out:
# State or Province
# California              214
# New York                129
# Texas                   124
# Florida                 123
# Illinois                 88
# Ohio                     81
# Michigan                 66
# Washington               61
# Indiana                  53
# Pennsylvania             52
# Minnesota                51
# Virginia                 51
# North Carolina           49
# Massachusetts            46
# Colorado                 44
# Georgia                  44
# Tennessee                41
# Wisconsin                39
# Utah                     38
# Iowa                     38
# Maryland                 34
# New Jersey               32
# Arizona                  31
# South Carolina           30
# Oregon                   28
# Missouri                 27
# Maine                    27
# Kansas                   27
# Alabama                  22
# Kentucky                 22
# Arkansas                 22
# Louisiana                20
# ...

# %% [markdown]
# # top 5 name code

# %%
data["State or Province"].value_counts()[:5]
# Out:
# State or Province
# California    214
# New York      129
# Texas         124
# Florida       123
# Illinois       88
# Name: count, dtype: int64

# %%
plt.figure(figsize=(50,49))
sns.countplot(y="State or Province", data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Product Base Margin check

# %%
plt.figure(figsize=(5, 4))  # Set the figure size
sns.barplot(x="Product Category", y="Product Base Margin", data=data, estimator='sum')
plt.show()
